# %%
# !pip install moabb==1.0.0
# !pip install pyriemann==0.5
# !pip install qiskit==0.45.0
# !pip install qiskit_machine_learning==0.7.1
# Out:
# Requirement already satisfied: moabb==1.0.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (1.0.0)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (6.0.1)
# Requirement already satisfied: coverage<8.0.0,>=7.0.1 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (7.4.1)
# Requirement already satisfied: edflib-python<2.0.0,>=1.0.6 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (1.0.8)
# Requirement already satisfied: h5py<=3.8.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (3.8.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.6.2 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (3.8.0)
# Requirement already satisfied: memory-profiler<0.62.0,>=0.61.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (0.61.0)
# Requirement already satisfied: mne<2.0,>=1.4 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (1.6.1)
# Requirement already satisfied: mne-bids<0.14,>=0.13 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (0.13)
# Requirement already satisfied: numpy<2.0,>=1.22 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (1.26.2)
# Requirement already satisfied: pandas<2.0.0,>=1.5.2 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (1.5.3)
# Requirement already satisfied: pooch<2.0.0,>=1.6.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (1.8.0)
# Requirement already satisfied: pyriemann<0.6,>=0.5 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (0.5)
# Requirement already satisfied: pytest<8.0.0,>=7.4.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (7.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (2.31.0)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (1.4.0)
# Requirement already satisfied: scipy<2.0.0,>=1.9.3 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (1.11.4)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.1 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (0.12.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (4.66.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.15 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from moabb==1.0.0) (1.26.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb==1.0.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb==1.0.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb==1.0.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb==1.0.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb==1.0.0) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb==1.0.0) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb==1.0.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb==1.0.0) (2.8.2)
# Requirement already satisfied: psutil in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from memory-profiler<0.62.0,>=0.61.0->moabb==1.0.0) (5.9.0)
# Requirement already satisfied: decorator in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from mne<2.0,>=1.4->moabb==1.0.0) (5.1.1)
# Requirement already satisfied: jinja2 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from mne<2.0,>=1.4->moabb==1.0.0) (3.1.2)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from mne<2.0,>=1.4->moabb==1.0.0) (0.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from pandas<2.0.0,>=1.5.2->moabb==1.0.0) (2023.3.post1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from pooch<2.0.0,>=1.6.0->moabb==1.0.0) (3.10.0)
# Requirement already satisfied: joblib in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from pyriemann<0.6,>=0.5->moabb==1.0.0) (1.3.2)
# Requirement already satisfied: iniconfig in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb==1.0.0) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb==1.0.0) (1.4.0)
# Requirement already satisfied: colorama in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb==1.0.0) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from requests<3.0.0,>=2.28.1->moabb==1.0.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from requests<3.0.0,>=2.28.1->moabb==1.0.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from requests<3.0.0,>=2.28.1->moabb==1.0.0) (2023.11.17)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from scikit-learn<2.0.0,>=1.2.0->moabb==1.0.0) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.6.2->moabb==1.0.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from jinja2->mne<2.0,>=1.4->moabb==1.0.0) (2.1.1)
# Requirement already satisfied: pyriemann==0.5 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (0.5)
# Requirement already satisfied: numpy!=1.24.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from pyriemann==0.5) (1.26.2)
# Requirement already satisfied: scipy in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from pyriemann==0.5) (1.11.4)
# Requirement already satisfied: scikit-learn in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from pyriemann==0.5) (1.4.0)
# Requirement already satisfied: joblib in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from pyriemann==0.5) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from scikit-learn->pyriemann==0.5) (3.2.0)
# Requirement already satisfied: qiskit==0.45.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (0.45.0)
# Requirement already satisfied: qiskit-terra==0.45.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit==0.45.0) (0.45.0)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit==0.45.0) (0.13.2)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit==0.45.0) (1.26.2)
# Requirement already satisfied: ply>=3.10 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit==0.45.0) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit==0.45.0) (5.9.0)
# Requirement already satisfied: scipy>=1.5 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit==0.45.0) (1.11.4)
# Requirement already satisfied: sympy>=1.3 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit==0.45.0) (1.12)
# Requirement already satisfied: dill>=0.3 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit==0.45.0) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit==0.45.0) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit==0.45.0) (5.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.0->qiskit==0.45.0) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.0->qiskit==0.45.0) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from sympy>=1.3->qiskit-terra==0.45.0->qiskit==0.45.0) (1.3.0)
# Requirement already satisfied: qiskit_machine_learning==0.7.1 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (0.7.1)
# Requirement already satisfied: qiskit>=0.44 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit_machine_learning==0.7.1) (0.45.0)
# Requirement already satisfied: qiskit-algorithms>=0.2.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit_machine_learning==0.7.1) (0.2.2)
# Requirement already satisfied: scipy>=1.4 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit_machine_learning==0.7.1) (1.11.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit_machine_learning==0.7.1) (1.26.2)
# Requirement already satisfied: psutil>=5 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit_machine_learning==0.7.1) (5.9.0)
# Requirement already satisfied: scikit-learn>=1.2.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit_machine_learning==0.7.1) (1.4.0)
# Requirement already satisfied: fastdtw in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit_machine_learning==0.7.1) (0.3.4)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit_machine_learning==0.7.1) (68.2.2)
# Requirement already satisfied: dill>=0.3.4 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit_machine_learning==0.7.1) (0.3.7)
# Requirement already satisfied: qiskit-terra==0.45.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit>=0.44->qiskit_machine_learning==0.7.1) (0.45.0)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44->qiskit_machine_learning==0.7.1) (0.13.2)
# Requirement already satisfied: ply>=3.10 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44->qiskit_machine_learning==0.7.1) (3.11)
# Requirement already satisfied: sympy>=1.3 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44->qiskit_machine_learning==0.7.1) (1.12)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44->qiskit_machine_learning==0.7.1) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from qiskit-terra==0.45.0->qiskit>=0.44->qiskit_machine_learning==0.7.1) (5.1.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from scikit-learn>=1.2.0->qiskit_machine_learning==0.7.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from scikit-learn>=1.2.0->qiskit_machine_learning==0.7.1) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.0->qiskit>=0.44->qiskit_machine_learning==0.7.1) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.0->qiskit>=0.44->qiskit_machine_learning==0.7.1) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\newah\appdata\local\anaconda3\envs\qc\lib\site-packages (from sympy>=1.3->qiskit-terra==0.45.0->qiskit>=0.44->qiskit_machine_learning==0.7.1) (1.3.0)

# %%
"""
TODO

"""

# Modified from plot_classify_EEG_tangentspace.py of pyRiemann
# License: BSD (3-clause)

from matplotlib import pyplot as plt
import warnings
import seaborn as sns
from moabb import set_log_level
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from pyriemann.tangentspace import TangentSpace
from pyriemann.estimation import XdawnCovariances, ERPCovariances
from pyriemann.preprocessing import Whitening
from moabb.datasets import (
    # bi2012,
    # bi2013a,
    # bi2014a,
    # bi2014b,
    # bi2015a,
    # bi2015b,
    # BNCI2014008,
    BNCI2014009,
    # BNCI2015003,
    # EPFLP300,
    # Lee2019_ERP,
)
from sklearn.base import BaseEstimator, TransformerMixin
from qword_dataset import Neuroergonomics2021Dataset
from moabb.evaluations import WithinSessionEvaluation, CrossSessionEvaluation
from moabb.paradigms import P300
from sklearn.decomposition import PCA

# inject convex distance and mean to pyriemann (if not done already)
# from pyriemann_qiskit.utils import distance, mean  # noqa
# from pyriemann_qiskit.pipelines import (
#     QuantumMDMVotingClassifier,
#     QuantumMDMWithRiemannianPipeline,
# )
from sklearn.pipeline import make_pipeline
from autoencoders import BasicQnnAutoencoder
from pyriemann.spatialfilters import Xdawn
print(__doc__)

##############################################################################
# getting rid of the warnings about the future
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=RuntimeWarning)

warnings.filterwarnings("ignore")

set_log_level("info")

##############################################################################
# Initialization
# ----------------
#
# 1) Create paradigm
# 2) Load datasets
from moabb.paradigms import RestingStateToP300Adapter
events = dict(easy=2, medium=3)
paradigm = RestingStateToP300Adapter(events=events, tmin=0, tmax=0.5)

# paradigm = P300()

# Datasets:
# name, electrodes, subjectsaaaaa
# bi2013a	    16	24 (normal)
# bi2014a    	16	64 (usually low performance)
# BNCI2014009	16	10 (usually high performance)
# BNCI2014008	 8	 8
# BNCI2015003	 8	10
# bi2015a        32  43
# bi2015b        32  44

datasets = [Neuroergonomics2021Dataset()]

# reduce the number of subjects, the Quantum pipeline takes a lot of time
# if executed on the entire dataset
n_subjects = 2
title = "Datasets: "
for dataset in datasets:
    title = title + " " + dataset.code
    dataset.subject_list = dataset.subject_list[0:n_subjects]

# Change this to true to test the quantum optimizer
quantum = False

##############################################################################
# We have to do this because the classes are called 'Target' and 'NonTarget'
# but the evaluation function uses a LabelEncoder, transforming them
# to 0 and 1
labels_dict = {"Target": 1, "NonTarget": 0}

##############################################################################
# Create Pipelines
# ----------------
#
# Pipelines must be a dict of sklearn pipeline transformer.

pipelines = {}

# pipelines["mean=convex/distance=euclid"] = QuantumMDMWithRiemannianPipeline(
#     convex_metric="mean", quantum=quantum
# )

# pipelines["mean=logeuclid/distance=convex"] = QuantumMDMWithRiemannianPipeline(
#     convex_metric="distance", quantum=quantum
# )

class Vectorizer(TransformerMixin):
    def __init__(self, is_even=True):
        self.is_even = is_even

    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        n_trial, n_features, n_samples = X.shape
        print(X.shape)
        return X.reshape((n_trial, n_features * n_samples))

class Devectorizer(TransformerMixin):
    def __init__(self, is_even=True):
        self.is_even = is_even

    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        n_trial, _= X.shape
        print(X.shape)
        return X.reshape((n_trial, 4, 64))

pipelines["LDA_denoised"] = make_pipeline(
    # select only 2 components
    Xdawn(nfilter=2),
    Vectorizer(),
    BasicQnnAutoencoder(5, 3),
    Devectorizer(),
    ERPCovariances(),
    TangentSpace(),
    # PCA(n_components=4),
    LDA()
)

pipelines["LDA"] = make_pipeline(
    Xdawn(nfilter=2),
    # Vectorizer(),
    # Devectorizer(),
    ERPCovariances(),
    # Whitening(dim_red={"n_components": 2}),
    TangentSpace(), 
    # PCA(n_components=4),
    LDA()
)

##############################################################################
# Run evaluation
# ----------------
#
# Compare the pipeline using a within session evaluation.

# Here should be cross session
evaluation = CrossSessionEvaluation(
    paradigm=paradigm,
    datasets=datasets,
    overwrite=True,
)

results = evaluation.process(pipelines)

print("Averaging the session performance:")
print(results.groupby("pipeline").mean("score")[["score", "time"]])


# ##############################################################################
# # Plot Results
# # ----------------
# #
# # Here we plot the results to compare two pipelines

fig, ax = plt.subplots(facecolor="white", figsize=[8, 4])

sns.stripplot(
    data=results,
    y="score",
    x="pipeline",
    ax=ax,
    jitter=True,
    alpha=0.5,
    zorder=1,
    palette="Set1",
)
sns.pointplot(data=results, y="score", x="pipeline", ax=ax, palette="Set1").set(
    title=title
)

ax.set_ylabel("ROC AUC")
ax.set_ylim(0.3, 1)

plt.show()
# Out:
# 2024-02-10 12:37:22,279 WARNING MainThread moabb.datasets.base The dataset class name 'Neuroergonomics2021Dataset' must be an abbreviation of its code 'Neuroergonomics2021'. See moabb.datasets.base.is_abbrev for more information.
# 2024-02-10 12:37:22,294 INFO MainThread moabb.evaluations.base Processing dataset: Neuroergonomics2021
# TODO
# Neuroergonomics2021-CrossSession:   0%|                                                          | 0/2 [00:13<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 173
#     160 ##############################################################################
#     161 # Run evaluation
#     162 # ----------------
#    (...)
#     165
#     166 # Here should be cross session
#     167 evaluation = CrossSessionEvaluation(
#     168     paradigm=paradigm,
#     169     datasets=datasets,
#     170     overwrite=True,
#     171 )
# --> 173 results = evaluation.process(pipelines)
#     175 print("Averaging the session performance:")
#     176 print(results.groupby("pipeline").mean("score")[["score", "time"]])
#
# File ~\AppData\Local\anaconda3\envs\qc\Lib\site-packages\moabb\evaluations\base.py:188, in BaseEvaluation.process(self, pipelines, param_grid, postprocess_pipeline)
#     179     # (we only keep the pipeline for the first frequency band, better ideas?)
#     181     results = self.evaluate(
#     182         dataset,
#     183         pipelines,
#    (...)
#     186         postprocess_pipeline=postprocess_pipeline,
#     187     )
# --> 188     for res in results:
#     189         self.push_result(res, pipelines, process_pipeline)
#     191 return self.results.to_dataframe(
#     192     pipelines=pipelines, process_pipeline=process_pipeline
#     193 )
#
# File ~\AppData\Local\anaconda3\envs\qc\Lib\site-packages\moabb\evaluations\evaluations.py:548, in CrossSessionEvaluation.evaluate(self, dataset, pipelines, param_grid, process_pipeline, postprocess_pipeline)
#     542         save_model_cv(
#     543             model=cvclf,
#     544             save_path=model_save_path,
#     545             cv_index=str(cv_ind),
#     546         )
#     547 else:
# --> 548     result = _fit_and_score(
#     549         clone(grid_clf),
#     550         X,
#     551         y,
#     552         scorer,
#     553         train,
#     554         test,
#     555         verbose=False,
#     556         parameters=None,
#     557         fit_params=None,
#     558         error_score=self.error_score,
#     559         return_estimator=True,
#     560     )
#     561     score = result["test_scores"]
#     562     model_list = result["estimator"]
#
# TypeError: _fit_and_score() takes 3 positional arguments but 6 positional arguments (and 5 keyword-only arguments) were given
